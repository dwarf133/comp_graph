# %%
from PIL import Image, ImageDraw

path_to_row_image = "uncolored_cirqle.png"
img = Image.open(path_to_row_image)

size = img.size
width, height = size
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
LIGHT_BLUE = (135, 206, 250)


drawMatrix = [[3 if img.getpixel((i, j)) == WHITE else 2 for i in range(0, width)] for j in range(0, height)]
filled = 0
poped = 0
stack = []

stack.append((width//2, height//2))

while len(stack) != 0:
    pixel = stack.pop(-1)
    y, x = pixel
    print(f'Вытащил и закрасил пиксель: {(x, y)}')
    poped += 1
    filled += 1
    drawMatrix[y][x] = 2
    x_temp = x
    x += 1
    print('Пошел направо')
    while drawMatrix[y][x] != 1:
        drawMatrix[y][x] = 2
        print(f'Закрасил пиксель {(x, y)}')
        filled += 1
        x += 1
    x_right = x - 1
    x = x_temp
    x -= 1
    print('Пошел налево')
    while drawMatrix[y][x] != 1:
        drawMatrix[y][x] = 2
        print(f'Закрасил пиксель {(x, y)}')
        filled += 1
        x -= 1
    x_left = x + 1
    x = x_left
    y -= 1
    print('Пошел вверх')
    while(x <= x_right):
        flag = False
        while drawMatrix[y][x] != 2 and drawMatrix[y][x] != 1 and x < x_right:
            if not flag:
                flag = True
            print('Пошел направо в поисках незакрашенных пикселей')
            x += 1
        if flag:
            if x == x_right and drawMatrix[y][x] != 1 and drawMatrix != 2:
                print(f'Добавил пиксель {(x, y)} в стек')
                stack.append((y, x))
            else:
                print(f'Добавил пиксель {(x - 1, y)} в стек')
                stack.append((y, x - 1))
            flag = False
        x_enter = x
        while (drawMatrix[y][x] == 2 or drawMatrix[y][x] == 1) and x < x_right:
            print('Пошел направо в последнем while')
            x += 1
        if x == x_enter:
            print('Пошел направо в последнем if')
            x += 1
    x = x_left
    y += 2
    print('Пошел вниз')
    while(x <= x_right):
        flag = False
        while drawMatrix[y][x] != 2 and drawMatrix[y][x] != 1 and x < x_right:
            if not flag:
                flag = True
            print('Пошел направо в поисках незакрашенных пикселей')
            x += 1
        if flag:
            if x == x_right and drawMatrix[y][x] != 1 and drawMatrix != 2:
                print(f'Добавил пиксель {(x, y)} в стек')
                stack.append((y, x))
            else:
                print(f'Добавил пиксель {(x - 1, y)} в стек')
                stack.append((y, x - 1))
            flag = False
        x_enter = x
        while (drawMatrix[y][x] == 2 or drawMatrix[y][x] == 1) and x < x_right:
            print('Пошел направо в последнем while')
            x += 1
        if x == x_enter:
            print('Пошел направо в последнем if')
            x += 1

idDraw = ImageDraw.Draw(img)
for i in range(0, width):
    for j in range(0, height):
        if(drawMatrix[i][j] == 2):
            idDraw.point((i, j), fill=LIGHT_BLUE)

print('Готово!')
print(f'Закрашено пикселей: {filled}')
print(f'Всего было в стеке пикселей: {poped}')
print(f'Зря побывало в стеке пикселей: {(((poped - filled) * 100) / poped):.2f} %')

img.save("line_colored_cirqle.png")
# Out:
# Вытащил и закрасил пиксель: (219, 239)
# Пошел направо
# Закрасил пиксель (220, 239)
# Закрасил пиксель (221, 239)
# Закрасил пиксель (222, 239)
# Закрасил пиксель (223, 239)
# Закрасил пиксель (224, 239)
# Закрасил пиксель (225, 239)
# Закрасил пиксель (226, 239)
# Закрасил пиксель (227, 239)
# Закрасил пиксель (228, 239)
# Закрасил пиксель (229, 239)
# Закрасил пиксель (230, 239)
# Закрасил пиксель (231, 239)
# Закрасил пиксель (232, 239)
# Закрасил пиксель (233, 239)
# Закрасил пиксель (234, 239)
# Закрасил пиксель (235, 239)
# Закрасил пиксель (236, 239)
# Закрасил пиксель (237, 239)
# Закрасил пиксель (238, 239)
# Закрасил пиксель (239, 239)
# Закрасил пиксель (240, 239)
# Закрасил пиксель (241, 239)
# Закрасил пиксель (242, 239)
# Закрасил пиксель (243, 239)
# Закрасил пиксель (244, 239)
# Закрасил пиксель (245, 239)
# Закрасил пиксель (246, 239)
# Закрасил пиксель (247, 239)
# Закрасил пиксель (248, 239)
# Закрасил пиксель (249, 239)
# Закрасил пиксель (250, 239)
# Закрасил пиксель (251, 239)
# Закрасил пиксель (252, 239)
# Закрасил пиксель (253, 239)
# Закрасил пиксель (254, 239)
# Закрасил пиксель (255, 239)
# Закрасил пиксель (256, 239)
# Закрасил пиксель (257, 239)
# Закрасил пиксель (258, 239)
# Закрасил пиксель (259, 239)
# Закрасил пиксель (260, 239)
# Закрасил пиксель (261, 239)
# Закрасил пиксель (262, 239)
# Закрасил пиксель (263, 239)
# Закрасил пиксель (264, 239)
# Закрасил пиксель (265, 239)
# Закрасил пиксель (266, 239)
# Закрасил пиксель (267, 239)
# Закрасил пиксель (268, 239)
# Закрасил пиксель (269, 239)
# Закрасил пиксель (270, 239)
# Закрасил пиксель (271, 239)
# Закрасил пиксель (272, 239)
# Закрасил пиксель (273, 239)
# Закрасил пиксель (274, 239)
# Закрасил пиксель (275, 239)
# Закрасил пиксель (276, 239)
# Закрасил пиксель (277, 239)
# Закрасил пиксель (278, 239)
# Закрасил пиксель (279, 239)
# Закрасил пиксель (280, 239)
# Закрасил пиксель (281, 239)
# Закрасил пиксель (282, 239)
# Закрасил пиксель (283, 239)
# Закрасил пиксель (284, 239)
# Закрасил пиксель (285, 239)
# Закрасил пиксель (286, 239)
# Закрасил пиксель (287, 239)
# Закрасил пиксель (288, 239)
# Закрасил пиксель (289, 239)
# Закрасил пиксель (290, 239)
# Закрасил пиксель (291, 239)
# Закрасил пиксель (292, 239)
# Закрасил пиксель (293, 239)
# Закрасил пиксель (294, 239)
# Закрасил пиксель (295, 239)
# Закрасил пиксель (296, 239)
# Закрасил пиксель (297, 239)
# Закрасил пиксель (298, 239)
# Закрасил пиксель (299, 239)
# Закрасил пиксель (300, 239)
# Закрасил пиксель (301, 239)
# Закрасил пиксель (302, 239)
# Закрасил пиксель (303, 239)
# Закрасил пиксель (304, 239)
# Закрасил пиксель (305, 239)
# Закрасил пиксель (306, 239)
# Закрасил пиксель (307, 239)
# Закрасил пиксель (308, 239)
# Закрасил пиксель (309, 239)
# Закрасил пиксель (310, 239)
# Закрасил пиксель (311, 239)
# Закрасил пиксель (312, 239)
# Закрасил пиксель (313, 239)
# Закрасил пиксель (314, 239)
# Закрасил пиксель (315, 239)
# Закрасил пиксель (316, 239)
# Закрасил пиксель (317, 239)
# Закрасил пиксель (318, 239)
# Закрасил пиксель (319, 239)
# Закрасил пиксель (320, 239)
# Закрасил пиксель (321, 239)
# Закрасил пиксель (322, 239)
# Закрасил пиксель (323, 239)
# Закрасил пиксель (324, 239)
# Закрасил пиксель (325, 239)
# Закрасил пиксель (326, 239)
# Закрасил пиксель (327, 239)
# Закрасил пиксель (328, 239)
# Закрасил пиксель (329, 239)
# Закрасил пиксель (330, 239)
# Закрасил пиксель (331, 239)
# Закрасил пиксель (332, 239)
# Закрасил пиксель (333, 239)
# Закрасил пиксель (334, 239)
# Закрасил пиксель (335, 239)
# Закрасил пиксель (336, 239)
# Закрасил пиксель (337, 239)
# Закрасил пиксель (338, 239)
# Закрасил пиксель (339, 239)
# Закрасил пиксель (340, 239)
# Закрасил пиксель (341, 239)
# Закрасил пиксель (342, 239)
# Закрасил пиксель (343, 239)
# Закрасил пиксель (344, 239)
# Закрасил пиксель (345, 239)
# Закрасил пиксель (346, 239)
# Закрасил пиксель (347, 239)
# Закрасил пиксель (348, 239)
# Закрасил пиксель (349, 239)
# Закрасил пиксель (350, 239)
# Закрасил пиксель (351, 239)
# Закрасил пиксель (352, 239)
# Закрасил пиксель (353, 239)
# Закрасил пиксель (354, 239)
# Закрасил пиксель (355, 239)
# Закрасил пиксель (356, 239)
# Закрасил пиксель (357, 239)
# Закрасил пиксель (358, 239)
# Закрасил пиксель (359, 239)
# Закрасил пиксель (360, 239)
# Закрасил пиксель (361, 239)
# Закрасил пиксель (362, 239)
# Закрасил пиксель (363, 239)
# Закрасил пиксель (364, 239)
# Закрасил пиксель (365, 239)
# Закрасил пиксель (366, 239)
# Закрасил пиксель (367, 239)
# Закрасил пиксель (368, 239)
# Закрасил пиксель (369, 239)
# Закрасил пиксель (370, 239)
# Закрасил пиксель (371, 239)
# Закрасил пиксель (372, 239)
# Закрасил пиксель (373, 239)
# Закрасил пиксель (374, 239)
# Закрасил пиксель (375, 239)
# Закрасил пиксель (376, 239)
# Закрасил пиксель (377, 239)
# Закрасил пиксель (378, 239)
# Закрасил пиксель (379, 239)
# Закрасил пиксель (380, 239)
# Закрасил пиксель (381, 239)
# Закрасил пиксель (382, 239)
# Закрасил пиксель (383, 239)
# Закрасил пиксель (384, 239)
# Закрасил пиксель (385, 239)
# Закрасил пиксель (386, 239)
# Закрасил пиксель (387, 239)
# Закрасил пиксель (388, 239)
# Закрасил пиксель (389, 239)
# Закрасил пиксель (390, 239)
# Закрасил пиксель (391, 239)
# Закрасил пиксель (392, 239)
# Закрасил пиксель (393, 239)
# Закрасил пиксель (394, 239)
# Закрасил пиксель (395, 239)
# Закрасил пиксель (396, 239)
# Закрасил пиксель (397, 239)
# Закрасил пиксель (398, 239)
# Закрасил пиксель (399, 239)
# Закрасил пиксель (400, 239)
# Закрасил пиксель (401, 239)
# Закрасил пиксель (402, 239)
# Закрасил пиксель (403, 239)
# Закрасил пиксель (404, 239)
# Закрасил пиксель (405, 239)
# Закрасил пиксель (406, 239)
# Закрасил пиксель (407, 239)
# Закрасил пиксель (408, 239)
# Закрасил пиксель (409, 239)
# Закрасил пиксель (410, 239)
# Закрасил пиксель (411, 239)
# Закрасил пиксель (412, 239)
# Закрасил пиксель (413, 239)
# Закрасил пиксель (414, 239)
# Закрасил пиксель (415, 239)
# Закрасил пиксель (416, 239)
# Закрасил пиксель (417, 239)
# Закрасил пиксель (418, 239)
# Закрасил пиксель (419, 239)
# Закрасил пиксель (420, 239)
# Закрасил пиксель (421, 239)
# Закрасил пиксель (422, 239)
# Закрасил пиксель (423, 239)
# Закрасил пиксель (424, 239)
# Закрасил пиксель (425, 239)
# Закрасил пиксель (426, 239)
# Закрасил пиксель (427, 239)
# Закрасил пиксель (428, 239)
# Закрасил пиксель (429, 239)
# Закрасил пиксель (430, 239)
# Закрасил пиксель (431, 239)
# Закрасил пиксель (432, 239)
# Закрасил пиксель (433, 239)
# Закрасил пиксель (434, 239)
# Закрасил пиксель (435, 239)
# Закрасил пиксель (436, 239)
# Закрасил пиксель (437, 239)
# Закрасил пиксель (438, 239)
# Закрасил пиксель (439, 239)
# Закрасил пиксель (440, 239)
# Закрасил пиксель (441, 239)
# Закрасил пиксель (442, 239)
# Закрасил пиксель (443, 239)
# Закрасил пиксель (444, 239)
# Закрасил пиксель (445, 239)
# Закрасил пиксель (446, 239)
# Закрасил пиксель (447, 239)
# Закрасил пиксель (448, 239)
# Закрасил пиксель (449, 239)
# Закрасил пиксель (450, 239)
# Закрасил пиксель (451, 239)
# Закрасил пиксель (452, 239)
# Закрасил пиксель (453, 239)
# Закрасил пиксель (454, 239)
# Закрасил пиксель (455, 239)
# Закрасил пиксель (456, 239)
# Закрасил пиксель (457, 239)
# Закрасил пиксель (458, 239)
# Закрасил пиксель (459, 239)
# Закрасил пиксель (460, 239)
# Закрасил пиксель (461, 239)
# Закрасил пиксель (462, 239)
# Закрасил пиксель (463, 239)
# Закрасил пиксель (464, 239)
# Закрасил пиксель (465, 239)
# Закрасил пиксель (466, 239)
# Закрасил пиксель (467, 239)
# Закрасил пиксель (468, 239)
# Закрасил пиксель (469, 239)
# Закрасил пиксель (470, 239)
# Закрасил пиксель (471, 239)
# Закрасил пиксель (472, 239)
# Закрасил пиксель (473, 239)
# Закрасил пиксель (474, 239)
# Закрасил пиксель (475, 239)
# Закрасил пиксель (476, 239)
# Закрасил пиксель (477, 239)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/siba/Documents/comp_graph/line_fill.ipynb Cell 1' in <cell line: 20>()
#      <a href='vscode-notebook-cell:/home/siba/Documents/comp_graph/line_fill.ipynb#ch0000000?line=27'>28</a> x += 1
#      <a href='vscode-notebook-cell:/home/siba/Documents/comp_graph/line_fill.ipynb#ch0000000?line=28'>29</a> print('Пошел направо')
# ---> <a href='vscode-notebook-cell:/home/siba/Documents/comp_graph/line_fill.ipynb#ch0000000?line=29'>30</a> while drawMatrix[y][x] != 1:
#      <a href='vscode-notebook-cell:/home/siba/Documents/comp_graph/line_fill.ipynb#ch0000000?line=30'>31</a>     drawMatrix[y][x] = 2
#      <a href='vscode-notebook-cell:/home/siba/Documents/comp_graph/line_fill.ipynb#ch0000000?line=31'>32</a>     print(f'Закрасил пиксель {(x, y)}')
#
# IndexError: list index out of range
